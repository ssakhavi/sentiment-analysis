# %%
import nltk
from nltk.corpus import opinion_lexicon
from nltk import tokenize
import string  
import math
from textblob import TextBlob
# nltk.download('punkt')
# nltk.download('opinion_lexicon')
# nltk.download('stopwords')
  
len(opinion_lexicon.negative())

print(string.punctuation)

for punc in string.punctuation:
    for word in opinion_lexicon.positive():
        print(word) if "b" in word else None
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/siavash/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# abound
# abounds
# abundance
# abundant
# accessable
# accessible
# achievable
# achievible
# adaptable
# adjustable
# admirable
# admirably
# adorable
# affability
# affable
# affably
# affordable
# affordably
# afordable
# agreeable
# agreeableness
# agreeably
# ambitious
# ambitiously
# amenable
# amiability
# amiabily
# amiable
# amicability
# amicable
# amicably
# appreciable
# audible
# audibly
# available
# backbone
# balanced
# bargain
# beauteous
# beautiful
# beautifullly
# beautifully
# beautify
# beauty
# beckon
# beckoned
# beckoning
# beckons
# believable
# believeable
# beloved
# benefactor
# beneficent
# beneficial
# beneficially
# beneficiary
# benefit
# benefits
# benevolence
# benevolent
# benifits
# best
# best-known
# best-performing
# best-selling
# better
# better-known
# ...

# %%
if "abound" in opinion_lexicon.positive():
    print("yes")
# Out:
# yes

# %%
small_corpus_df = catalog.load("small_corpus")
small_corpus_df.head(5)
# Out:
# 2021-01-08 15:20:47,557 - kedro.io.data_catalog - INFO - Loading data from `small_corpus` (CSVDataSet)...
#    rating                                            reviews
# 0       1  Recently UBISOFT had to settle a huge class-ac...
# 1       1                 code didn't work, got me a refund.
# 2       1  these do not work at all, all i get is static ...
# 3       1  well let me start by saying that when i first ...
# 4       1  Dont waste your money, you will just end up us...

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from pprint import pprint
from sentiment_analysis.pipelines.data_engineering.nodes import calculate_sentiment_score,preprocess_sentences

sample_num = 2000
sample_review = small_corpus_df.iloc[sample_num]

print(f"\nReview Content:\n{sample_review.reviews}")

sentences = tokenize.sent_tokenize(sample_review.reviews)

print(f"\nTokenized Sentences:\n{sentences}")
sample_preprocess = preprocess_sentences(sentences)

print(f"\nPreprocessed Sentences(first Index):\n{sample_preprocess}")


overall_score = calculate_sentiment_score(sample_review)

print(f"\nOverall Score: {overall_score}")
print(f"Actual Rating: {sample_review.rating}")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
# Review Content:
# This game should have been
# an expansion pack to Sim Theme Park - and priced as such - as it's
# hardly a sequel.  If there are any major differences or improvements,
# I haven't found them yet.  You have three themed areas to choose from
# (Sim Theme Park had five) and you climb the corporate ladder by
# developing your park with various rides, managing your staff, and
# completing challenges that will ultimately allow you to progress to
# the next themed area.  The system requirements are steeper in this
# game and the load times are excruciating.  Don't listen to the box, you'll need at least a P350 and even then only if you have a
# fast video card or you'll be struggling.  If you do decide to change
# the screen resolution, the game shuts down without giving you the
# option to save your park first - a very irritating
# annoyance.
# ...
